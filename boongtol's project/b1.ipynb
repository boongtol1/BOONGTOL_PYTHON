# %%
import numpy as np
G1=np.array([[3,5,6,8,10,12],[-2,0,1,3,5,7],[-7,-5,-4,-2,0,2],[-12,-10,-9,-7,-5,-3],[-17,-15,-14,-12,-10,-8],[-22,-20,-19,-17,-15,-13]])
G2=np.array([[0,-1],[-1,-2],[1,0]])
current_string_number=input('현재 줄 번호를 입력하세요')
current_fret_number=input('현재 프렛 번호를 입력하세요')
current_degree=input('현재 도수를 입력하세요')
increase_degree=input('올릴 도수를 입력하세요')
drop_string_number=input('내릴 줄 개수를 입력하세요')

def second_degree():
    if int(increase_degree)==2:
        G1_second_degree=G1[:,0]
        kind_of_second_degree=input('장 or 단?')
        if kind_of_second_degree=='장':
            G2_second_degree=G2[0,:]
            if int(current_string_number)==6:
                if int(drop_string_number)==0:
                    after_fret_number=int(current_fret_number)+G1_second_degree[0]+G2_second_degree[1]
                    after_string_number=int(current_string_number)-int(drop_string_number)
                    after_degree=int(current_degree)+int(increase_degree)
                    return after_fret_number , after_string_number , after_degree
           
print(second_degree())
# Out:
# (6, 6, 5)

# %%
import numpy as np
G1=np.array([[3,5,6,8,10,12],[-2,0,1,3,5,7],[-7,-5,-4,-2,0,2],[-12,-10,-9,-7,-5,-3],[-17,-15,-14,-12,-10,-8],[-22,-20,-19,-17,-15,-13]])
G2=np.array([[0,-1],[-1,-2],[1,0]])
current_string_number=input('현재 줄 번호를 입력하세요')
current_fret_number=input('현재 프렛 번호를 입력하세요')
current_degree=input('현재 도수를 입력하세요')
increase_degree=input('올릴 도수를 입력하세요')
drop_string_number=input('내릴 줄 개수를 입력하세요')

def second_degree():
    if int(increase_degree)==2:
        G1_second_degree=G1[:,0]
        kind_of_second_degree=input('장 or 단?')
        if kind_of_second_degree=='장':
            G2_second_degree=G2[0,:]
            if int(current_string_number)==6:
                if int(drop_string_number)==0:
                    after_fret_number=int(current_fret_number)+G1_second_degree[0]+G2_second_degree[1]
                    after_string_number=int(current_string_number)-int(drop_string_number)
                    after_degree=int(current_degree)+int(increase_degree)
                    return after_fret_number , after_string_number , after_degree
           
print(second_degree())
# Out:
# 프렛 번호: 9, 줄 번호: 6, 도수: 5

# %%
import numpy as np

class GuitarDegreeCalculator:
    def __init__(self, G1, G2, current_string_number, current_fret_number, current_degree, increase_degree, drop_string_number):
        self.G1 = G1
        self.G2 = G2
        self.current_string_number = int(current_string_number)
        self.current_fret_number = int(current_fret_number)
        self.current_degree = int(current_degree)
        self.increase_degree = int(increase_degree)
        self.drop_string_number = int(drop_string_number)

    def second_degree(self):
        if self.increase_degree == 2:
            G1_second_degree = self.G1[:, 0]
            kind_of_second_degree = input('장 or 단? ')
            if kind_of_second_degree == '장':
                G2_second_degree = self.G2[0, :]
                if self.current_string_number == 6:
                    if self.drop_string_number == 0:
                        after_fret_number = self.current_fret_number + G1_second_degree[0] + G2_second_degree[1]
                        after_string_number = self.current_string_number - self.drop_string_number
                        after_degree = self.current_degree + self.increase_degree
                        return after_fret_number, after_string_number, after_degree
        return None, None, None

# 매트릭스 정의
G1 = np.array([[3, 5, 6, 8, 10, 12],
               [-2, 0, 1, 3, 5, 7],
               [-7, -5, -4, -2, 0, 2],
               [-12, -10, -9, -7, -5, -3],
               [-17, -15, -14, -12, -10, -8],
               [-22, -20, -19, -17, -15, -13]])

G2 = np.array([[0, -1],
               [-1, -2],
               [1, 0]])

# 사용자 입력
current_string_number = input('현재 줄 번호를 입력하세요: ')
current_fret_number = input('현재 프렛 번호를 입력하세요: ')
current_degree = input('현재 도수를 입력하세요: ')
increase_degree = input('올릴 도수를 입력하세요: ')
drop_string_number = input('내릴 줄 개수를 입력하세요: ')

# 객체 생성 및 함수 호출
calculator = GuitarDegreeCalculator(G1, G2, current_string_number, current_fret_number, current_degree, increase_degree, drop_string_number)
after_fret_number, after_string_number, after_degree = calculator.second_degree()

# 결과 출력
if after_fret_number is not None:
    print(f"프렛 번호: {after_fret_number}, 줄 번호: {after_string_number}, 도수: {after_degree}")
else:
    print("조건에 맞는 계산 결과가 없습니다.")

# %%
import numpy as np

class GuitarDegreeCalculator:
    def __init__(self, G1, G2, current_string_number, current_fret_number, current_degree, increase_degree):
        self.G1 = G1
        self.G2 = G2
        self.current_string_number = int(current_string_number)
        self.current_fret_number = int(current_fret_number)
        self.current_degree = int(current_degree)
        self.increase_degree = int(increase_degree)

    def second_degree(self, drop_string_number):
        if self.increase_degree == 2:
            G1_second_degree = self.G1[:, 0]
            kind_of_second_degree = input('장 or 단? ')
            if kind_of_second_degree == '장':
                G2_second_degree = self.G2[0, :]
                if self.current_string_number == 6:
                    if drop_string_number >= 0:
                        after_fret_number = self.current_fret_number + G1_second_degree[drop_string_number] + G2_second_degree[1]
                        after_string_number = self.current_string_number - drop_string_number
                        after_degree = self.current_degree + self.increase_degree
                        return after_fret_number, after_string_number, after_degree
        return None, None, None

# 매트릭스 정의
G1 = np.array([[3, 5, 6, 8, 10, 12],
               [-2, 0, 1, 3, 5, 7],
               [-7, -5, -4, -2, 0, 2],
               [-12, -10, -9, -7, -5, -3],
               [-17, -15, -14, -12, -10, -8],
               [-22, -20, -19, -17, -15, -13]])

G2 = np.array([[0, -1],
               [-1, -2],
               [1, 0]])

# 사용자 입력
current_string_number = input('현재 줄 번호를 입력하세요: ')
current_fret_number = input('현재 프렛 번호를 입력하세요: ')
current_degree = input('현재 도수를 입력하세요: ')
increase_degree = input('올릴 도수를 입력하세요: ')

# 객체 생성
calculator = GuitarDegreeCalculator(G1, G2, current_string_number, current_fret_number, current_degree, increase_degree)

# 자동으로 drop_string_number를 0부터 5까지 실행
for drop_string_number in range(6):
    after_fret_number, after_string_number, after_degree = calculator.second_degree(drop_string_number)
    if after_fret_number is not None:
        print(f"drop_string_number: {drop_string_number}, 프렛 번호: {after_fret_number}, 줄 번호: {after_string_number}, 도수: {after_degree}")
    else:
        print(f"drop_string_number: {drop_string_number}, 조건에 맞는 계산 결과가 없습니다.")
# Out:
# drop_string_number: 0, 프렛 번호: 6, 줄 번호: 6, 도수: 5
# drop_string_number: 1, 프렛 번호: 1, 줄 번호: 5, 도수: 5
# drop_string_number: 2, 프렛 번호: -4, 줄 번호: 4, 도수: 5
# drop_string_number: 3, 프렛 번호: -9, 줄 번호: 3, 도수: 5
# drop_string_number: 4, 프렛 번호: -14, 줄 번호: 2, 도수: 5
# drop_string_number: 5, 프렛 번호: -19, 줄 번호: 1, 도수: 5

# %%
import numpy as np

class GuitarDegreeCalculator:
    def __init__(self, G1, G2, current_string_number, current_fret_number, current_degree, increase_degree, kind_of_second_degree):
        self.G1 = G1
        self.G2 = G2
        self.current_string_number = int(current_string_number)
        self.current_fret_number = int(current_fret_number)
        self.current_degree = int(current_degree)
        self.increase_degree = int(increase_degree)
        self.kind_of_second_degree = kind_of_second_degree

    def second_degree(self, drop_string_number):
        if self.increase_degree == 2:
            G1_second_degree = self.G1[:, 0]
            if self.kind_of_second_degree == '장':
                G2_second_degree = self.G2[0, :]
            elif self.kind_of_second_degree == '단':
                G2_second_degree = self.G2[1, :]
            else:
                print("잘못된 입력입니다.")
                return None, None, None

            if self.current_string_number == 6:
                if drop_string_number >= 0:
                    after_fret_number = self.current_fret_number + G1_second_degree[drop_string_number] + G2_second_degree[1]
                    after_string_number = self.current_string_number - drop_string_number
                    after_degree = self.current_degree + self.increase_degree
                    return after_fret_number, after_string_number, after_degree
        return None, None, None

# 매트릭스 정의
G1 = np.array([[3, 5, 6, 8, 10, 12],
               [-2, 0, 1, 3, 5, 7],
               [-7, -5, -4, -2, 0, 2],
               [-12, -10, -9, -7, -5, -3],
               [-17, -15, -14, -12, -10, -8],
               [-22, -20, -19, -17, -15, -13]])

G2 = np.array([[0, -1],
               [-1, -2],
               [1, 0]])

# 사용자 입력
current_string_number = input('현재 줄 번호를 입력하세요: ')
current_fret_number = input('현재 프렛 번호를 입력하세요: ')
current_degree = input('현재 도수를 입력하세요: ')
increase_degree = input('올릴 도수를 입력하세요: ')
kind_of_second_degree = input('장 or 단? ')

# 객체 생성
calculator = GuitarDegreeCalculator(G1, G2, current_string_number, current_fret_number, current_degree, increase_degree, kind_of_second_degree)

# 자동으로 drop_string_number를 0부터 5까지 실행
for drop_string_number in range(6):
    after_fret_number, after_string_number, after_degree = calculator.second_degree(drop_string_number)
    if after_fret_number is not None:
        print(f"drop_string_number: {drop_string_number}, 프렛 번호: {after_fret_number}, 줄 번호: {after_string_number}, 도수: {after_degree}")
    else:
        print(f"drop_string_number: {drop_string_number}, 조건에 맞는 계산 결과가 없습니다.")
# Out:
# drop_string_number: 0, 프렛 번호: 5, 줄 번호: 6, 도수: 4
# drop_string_number: 1, 프렛 번호: 0, 줄 번호: 5, 도수: 4
# drop_string_number: 2, 프렛 번호: -5, 줄 번호: 4, 도수: 4
# drop_string_number: 3, 프렛 번호: -10, 줄 번호: 3, 도수: 4
# drop_string_number: 4, 프렛 번호: -15, 줄 번호: 2, 도수: 4
# drop_string_number: 5, 프렛 번호: -20, 줄 번호: 1, 도수: 4
